# %%
import pandas as pd
import numpy as np
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = '../database/recordings_processed/avanzados/20240505_113831_cuate_1/Xsens DOT_1_D422CD006775_20240502_122851.csv'

# %%
df = pd.read_csv(file)
df.head()
# Out:
#    PacketCounter  SampleTimeFine    Euler_X    Euler_Y     Euler_Z     Acc_X  \
# 0              0      1183857684  38.246029  56.364761 -116.339828  0.000000
# 1              1      1183874351  38.201138  56.369286 -116.431747 -8.451750
# 2              2      1183891018  38.159828  56.379364 -116.466011 -8.459953
# 3              3      1183907685  38.127850  56.390469 -116.494232 -8.457130
# 4              4      1183924352  38.105804  56.403831 -116.498985 -8.442103
#
#       Acc_Y     Acc_Z     Gyr_X     Gyr_Y     Gyr_Z
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  3.350621  4.162666 -0.802331 -1.452522 -2.354742
# 2  3.372897  4.167830 -1.233700 -1.040106 -2.173058
# 3  3.367533  4.194951 -1.529885 -0.612477 -1.770747
# 4  3.372266  4.223171 -1.528310 -0.290781 -1.541449

# %%
df['ElapsedTime'] = df['SampleTimeFine'].diff().cumsum()
df['ElapsedTime'] = df['ElapsedTime']/(10**6)

# %%
df.head()
for i in range():
    fff
    FileNotFoundErrorif
# Out:
#    PacketCounter  SampleTimeFine    Euler_X    Euler_Y     Euler_Z     Acc_X  \
# 0              0      1183857684  38.246029  56.364761 -116.339828  0.000000
# 1              1      1183874351  38.201138  56.369286 -116.431747 -8.451750
# 2              2      1183891018  38.159828  56.379364 -116.466011 -8.459953
# 3              3      1183907685  38.127850  56.390469 -116.494232 -8.457130
# 4              4      1183924352  38.105804  56.403831 -116.498985 -8.442103
#
#       Acc_Y     Acc_Z     Gyr_X     Gyr_Y     Gyr_Z  ElapsedTime
# 0  0.000000  0.000000  0.000000  0.000000  0.000000          NaN
# 1  3.350621  4.162666 -0.802331 -1.452522 -2.354742     0.016667
# 2  3.372897  4.167830 -1.233700 -1.040106 -2.173058     0.033334
# 3  3.367533  4.194951 -1.529885 -0.612477 -1.770747     0.050001
# 4  3.372266  4.223171 -1.528310 -0.290781 -1.541449     0.066668
